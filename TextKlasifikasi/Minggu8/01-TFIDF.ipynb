# %% [markdown]
# Praktek TF-IDF
# =============================

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_stem.csv',sep=';')

# %%
dataset.shape
# Out:
# (902, 10)

# %%
dataset.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
#
#                                                Tweet  Sentimen  \
# 0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
#
#                                               step01  \
# 0  cegah mata rantai covid   mari kita dirumah sa...
# 1  aku mohon yaallah semoga wabah covid   menghil...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                               tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
#
#                                         final_tokens  \
# 0  ['cegah', 'mata', 'rantai', 'covid', 'mari', '...
# 1  ['aku', 'mohon', 'yaallah', 'semoga', 'wabah',...
# 2  ['pemprov', 'papua', 'naikkan', 'status', 'jad...
#
#                                               step02  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                        finalText_str  \
# 0  cegah mata rantai covid mari kita dirumah saja...
# 1  aku mohon yaallah semoga wabah covid menghilan...
# 2  pemprov papua naikkan status jadi tanggap daru...
#
#                                        ProcessedText
# 0  cegah mata rantai covid kita rumah hingga hari...
# 1  aku mohon yaallah moga wabah covid hilang rama...
# 2  pemprov papua naik status jadi tanggap darurat...

# %%
dataset_feature = dataset['ProcessedText'].astype(str)

# %%
dataset_feature
# Out:
# 0      cegah mata rantai covid kita rumah hingga hari...
# 1      aku mohon yaallah moga wabah covid hilang rama...
# 2      pemprov papua naik status jadi tanggap darurat...
# 3                      covid nyampe prigen mbak hmm hoax
# 4      nyuruh orang pintar lu aja togog kerumun orang...
#                              ...
# 897    seluruh negara dunia alami masa sulit covid ra...
# 898    covid skripsi disaster selesai mau bgt bljr ma...
# 899    malam projek benda bincang malam fb satu belia...
# 900                          pontang panting koyak covid
# 901    masalah sekarang isu jangkit covid alaaaa bosa...
# Name: ProcessedText, Length: 902, dtype: str

# %%
dataset_label = dataset['Sentimen']

# %%
dataset_label
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      0.0
# 4     -1.0
#       ...
# 897    1.0
# 898    1.0
# 899    0.0
# 900   -1.0
# 901   -1.0
# Name: Sentimen, Length: 902, dtype: float64

# %% [markdown]
# # cek distribusi label

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 # Visualizing the target variable
#       2 plt.figure(figsize=(12,8))
# ----> 3 sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
#       4 plt.legend(loc='best')
#       5 plt.show()
#
# NameError: name 'sns' is not defined

# %%
dataset_label.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset_label.value_counts()
#
# NameError: name 'dataset_label' is not defined

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
vectorizer = TfidfVectorizer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 vectorizer = TfidfVectorizer()
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
positive_reviews = dataset[(dataset["Sentimen"] == 1)]
negative_reviews = dataset[(dataset["Sentimen"] == -1)]
neutral_reviews = dataset[(dataset["Sentimen"] == 0)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 positive_reviews = dataset[(dataset["Sentimen"] == 1)]
#       2 negative_reviews = dataset[(dataset["Sentimen"] == -1)]
#       3 neutral_reviews = dataset[(dataset["Sentimen"] == 0)]
#
# NameError: name 'dataset' is not defined

# %%
positive_reviews.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 positive_reviews.head()
#
# NameError: name 'positive_reviews' is not defined

# %%
Positive_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
Positive_tf_idf = Positive_tf_idf_vect.fit_transform(positive_reviews["ProcessedText"].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Positive_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
#       2 Positive_tf_idf = Positive_tf_idf_vect.fit_transform(positive_reviews["ProcessedText"].values)
#
# NameError: name 'TfidfVectorizer' is not defined

# %%
Positive_tf_idf.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 Positive_tf_idf.shape
#
# NameError: name 'Positive_tf_idf' is not defined

# %%
features = Positive_tf_idf_vect.get_feature_names()
# Out:
# /Users/masaboe/miniconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
idfValues = Positive_tf_idf_vect.idf_

# %%
d = dict(zip(features, 9 - idfValues))

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

# %%
for i in range(200):
    print(sortedDict[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 for i in range(200):
# ----> 2     print(sortedDict[i])
#
# NameError: name 'sortedDict' is not defined

# %%
# !pip3 install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plot
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 PlotWordCloud(d)
#
# NameError: name 'd' is not defined

# %% [markdown]
# # silakan lakukan untuk netral dan negative

# %%
data_netral = df[df['sentiment'] == 'netral'] 
data_negatif = df[df['sentiment'] == 'negatif']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data_netral = df[df['sentiment'] == 'netral']
#       2 data_negatif = df[df['sentiment'] == 'negatif']
#
# NameError: name 'df' is not defined

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Gabung semua teks netral menjadi satu string
text_netral = " ".join(review for review in data_netral.text)

# Buat objek WordCloud
wordcloud_netral = WordCloud(width=800, height=400, background_color='white').generate(text_netral)

# Tampilkan
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_netral, interpolation='bilinear')
plt.title("Word Cloud - Sentimen Netral")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plt
#       4 # Gabung semua teks netral menjadi satu string
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# Gabung semua teks negatif menjadi satu string
text_negatif = " ".join(review for review in data_negatif.text)

# Buat objek WordCloud 
wordcloud_negatif = WordCloud(width=800, height=400, background_color='black', colormap='Reds').generate(text_negatif)

# Tampilkan
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_negatif, interpolation='bilinear')
plt.title("Word Cloud - Sentimen Negatif")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Gabung semua teks negatif menjadi satu string
# ----> 2 text_negatif = " ".join(review for review in data_negatif.text)
#       4 # Buat objek WordCloud
#       5 wordcloud_negatif = WordCloud(width=800, height=400, background_color='black', colormap='Reds').generate(text_negatif)
#
# NameError: name 'data_negatif' is not defined
